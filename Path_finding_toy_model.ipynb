# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets
import torchvision.transforms as transforms
import numpy as np
import math
import time
import torch.nn.functional as F
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt 
class Functions(nn.Module):
    def __init__(self):
        super(Functions, self).__init__()

    def forward(self, x):
        well1 = -torch.exp(-3 * ((x[0] - 0.5)**2 + x[1]**2))
        well2 = -torch.exp(-3 * ((x[0] + 0.5)**2 + (x[1] + 0.5)**2))
        bump1 = torch.exp(-15 * ((x[0] + 0.2)**2 + (x[1] + 0.4)**2))
        bump2 = torch.exp(-15 * ((x[0] + 0.0)**2 + (x[1] - 0.3)**2))
        z=well1 + well2 + bump1 + bump2+1.0190055296306975
        return z.unsqueeze(0)

class FourierPathNN(nn.Module):
    def __init__(self,x1,x2, num_terms=10):
        super(FourierPathNN, self).__init__()
        self.num_terms = num_terms
        
        
        self.register_buffer('x1', x1.flatten())  # Store as a constant buffer
        self.register_buffer('x2', x2.flatten())  # Store as a constant buffer
        
        # Fourier coefficients for sine terms (b_n terms)
        self.b = nn.Parameter(torch.zeros(num_terms, x1.numel()))  # Learnable sine coefficients

    def forward(self, t_values):
        """
        Generate weights for a given t value (or array of t values).
        """
        t_values = t_values.view(-1, 1)
        a_0 = (1 - t_values) * self.x1 + t_values * self.x2
        sine_terms = torch.zeros_like(a_0)
        for n in range(1, self.num_terms + 1):
            sine_terms += self.b[n-1].view(1, -1) * torch.sin(n * torch.pi * t_values)
        weights = a_0 + sine_terms  # Combine a_0 and sine terms
        return weights.view(-1, *self.x1.shape)
    
def train_fourier_nn(path_model, cnn_model,num_terms, num_steps=300, lr=0.01):
    optimizer = optim.Adam(path_model.parameters(), lr=lr)
    t_values = torch.linspace(0, 1, 101).unsqueeze(1)  # 100 points between 0 and 1
    Min_Loss=None
    for step in range(num_steps):
        optimizer.zero_grad()
        path_weights = path_model(t_values)  # Generate weights along the path
        #Compute gradient of Loss along the path and L2 regularization. 
        loss,Data_array = loss_fn(path_weights, cnn_model,num_terms)
        loss.backward()
        for param in path_model.parameters():
            if param.grad is not None:
                param.grad += torch.randn_like(param.grad) * 1.0
        optimizer.step()
        if Min_Loss is None or Min_Loss > loss.item():
            Min_array=Data_array
            Min_Loss=loss.item()
            Min_path=path_weights
        #print(f"Step {step}/{num_steps}, Loss: {loss:.6f}")
    return Min_array,Min_path
def loss_fn(weights, cnn_model,num_terms,Lambda=35):
    """
    Compute the loss by injecting weights into the CNN model.
    """
    t_values = torch.linspace(0, 1, 101).unsqueeze(1)
    total_loss = 0.0
    Data_array=np.zeros(len(weights))
    Loss_sum=0.0
    criterion=nn.MSELoss()
    smoothness_loss = 0.0
#L2 regularization
    for j in range(len(weights) - 1):
        smoothness_loss += torch.norm(weights[j+1] - weights[j])**2
#Loss along the fourier path 
    for i in range(len(weights)):
        
        loss = criterion(cnn_model(weights[i]), torch.tensor([0],dtype=torch.float))
        total_loss += loss
        Data_array[i]=loss.item()
    print(total_loss,smoothness_loss)
    return total_loss+Lambda*smoothness_loss,Data_array
# Main Function
def main(x1,x2):
    # Initialize Models
    num_term=15
    fourier_nn = FourierPathNN(x1,x2,num_terms=num_term)

    # Initialize the FunctionalCNN
    cnn = Functions()

    # Train the FourierPathNN
    Min_array,Min_path=train_fourier_nn(fourier_nn, cnn,num_term)
    return Min_path
x1=torch.tensor([-0.62,-0.54])
x2=torch.tensor([0.49,-0.02])
Min_path=main(x1,x2)
# Out:
# tensor(35.5316, grad_fn=<AddBackward0>) tensor(1.2258, grad_fn=<AddBackward0>)
# tensor(28.1872, grad_fn=<AddBackward0>) tensor(1.4658, grad_fn=<AddBackward0>)
# tensor(23.1135, grad_fn=<AddBackward0>) tensor(1.2946, grad_fn=<AddBackward0>)
# tensor(19.5651, grad_fn=<AddBackward0>) tensor(1.3653, grad_fn=<AddBackward0>)
# tensor(16.8344, grad_fn=<AddBackward0>) tensor(1.4164, grad_fn=<AddBackward0>)
# tensor(14.6111, grad_fn=<AddBackward0>) tensor(1.3592, grad_fn=<AddBackward0>)
# tensor(12.5960, grad_fn=<AddBackward0>) tensor(1.3176, grad_fn=<AddBackward0>)
# tensor(10.8733, grad_fn=<AddBackward0>) tensor(1.3351, grad_fn=<AddBackward0>)
# tensor(9.5359, grad_fn=<AddBackward0>) tensor(1.3546, grad_fn=<AddBackward0>)
# tensor(8.5996, grad_fn=<AddBackward0>) tensor(1.3521, grad_fn=<AddBackward0>)
# tensor(7.9520, grad_fn=<AddBackward0>) tensor(1.3477, grad_fn=<AddBackward0>)
# tensor(7.4903, grad_fn=<AddBackward0>) tensor(1.3237, grad_fn=<AddBackward0>)
# tensor(7.1511, grad_fn=<AddBackward0>) tensor(1.3176, grad_fn=<AddBackward0>)
# tensor(6.8906, grad_fn=<AddBackward0>) tensor(1.3305, grad_fn=<AddBackward0>)
# tensor(6.6606, grad_fn=<AddBackward0>) tensor(1.3001, grad_fn=<AddBackward0>)
# tensor(6.4591, grad_fn=<AddBackward0>) tensor(1.2910, grad_fn=<AddBackward0>)
# tensor(6.2526, grad_fn=<AddBackward0>) tensor(1.2865, grad_fn=<AddBackward0>)
# tensor(6.0339, grad_fn=<AddBackward0>) tensor(1.2837, grad_fn=<AddBackward0>)
# tensor(5.8199, grad_fn=<AddBackward0>) tensor(1.2795, grad_fn=<AddBackward0>)
# tensor(5.6151, grad_fn=<AddBackward0>) tensor(1.2796, grad_fn=<AddBackward0>)
# tensor(5.4160, grad_fn=<AddBackward0>) tensor(1.2673, grad_fn=<AddBackward0>)
# tensor(5.2596, grad_fn=<AddBackward0>) tensor(1.2728, grad_fn=<AddBackward0>)
# tensor(5.1166, grad_fn=<AddBackward0>) tensor(1.2814, grad_fn=<AddBackward0>)
# tensor(4.9954, grad_fn=<AddBackward0>) tensor(1.2764, grad_fn=<AddBackward0>)
# tensor(4.9195, grad_fn=<AddBackward0>) tensor(1.2636, grad_fn=<AddBackward0>)
# tensor(4.8859, grad_fn=<AddBackward0>) tensor(1.2737, grad_fn=<AddBackward0>)
# tensor(4.8695, grad_fn=<AddBackward0>) tensor(1.2713, grad_fn=<AddBackward0>)
# tensor(4.8544, grad_fn=<AddBackward0>) tensor(1.2624, grad_fn=<AddBackward0>)
# tensor(4.8444, grad_fn=<AddBackward0>) tensor(1.2550, grad_fn=<AddBackward0>)
# tensor(4.8332, grad_fn=<AddBackward0>) tensor(1.2582, grad_fn=<AddBackward0>)
# tensor(4.8143, grad_fn=<AddBackward0>) tensor(1.2565, grad_fn=<AddBackward0>)
# tensor(4.7961, grad_fn=<AddBackward0>) tensor(1.2519, grad_fn=<AddBackward0>)
# tensor(4.7903, grad_fn=<AddBackward0>) tensor(1.2599, grad_fn=<AddBackward0>)
# tensor(4.8049, grad_fn=<AddBackward0>) tensor(1.2501, grad_fn=<AddBackward0>)
# tensor(4.8234, grad_fn=<AddBackward0>) tensor(1.2500, grad_fn=<AddBackward0>)
# tensor(4.8181, grad_fn=<AddBackward0>) tensor(1.2518, grad_fn=<AddBackward0>)
# tensor(4.7796, grad_fn=<AddBackward0>) tensor(1.2494, grad_fn=<AddBackward0>)
# tensor(4.6872, grad_fn=<AddBackward0>) tensor(1.2548, grad_fn=<AddBackward0>)
# tensor(4.5952, grad_fn=<AddBackward0>) tensor(1.2520, grad_fn=<AddBackward0>)
# tensor(4.5111, grad_fn=<AddBackward0>) tensor(1.2530, grad_fn=<AddBackward0>)
# tensor(4.4341, grad_fn=<AddBackward0>) tensor(1.2636, grad_fn=<AddBackward0>)
# tensor(4.3938, grad_fn=<AddBackward0>) tensor(1.2550, grad_fn=<AddBackward0>)
# tensor(4.3793, grad_fn=<AddBackward0>) tensor(1.2699, grad_fn=<AddBackward0>)
# tensor(4.3627, grad_fn=<AddBackward0>) tensor(1.2552, grad_fn=<AddBackward0>)
# tensor(4.3577, grad_fn=<AddBackward0>) tensor(1.2688, grad_fn=<AddBackward0>)
# tensor(4.3754, grad_fn=<AddBackward0>) tensor(1.2554, grad_fn=<AddBackward0>)
# tensor(4.4155, grad_fn=<AddBackward0>) tensor(1.2633, grad_fn=<AddBackward0>)
# tensor(4.4575, grad_fn=<AddBackward0>) tensor(1.2547, grad_fn=<AddBackward0>)
# tensor(4.4992, grad_fn=<AddBackward0>) tensor(1.2584, grad_fn=<AddBackward0>)
# tensor(4.5312, grad_fn=<AddBackward0>) tensor(1.2559, grad_fn=<AddBackward0>)
# tensor(4.5580, grad_fn=<AddBackward0>) tensor(1.2527, grad_fn=<AddBackward0>)
# tensor(4.5877, grad_fn=<AddBackward0>) tensor(1.2541, grad_fn=<AddBackward0>)
# tensor(4.5991, grad_fn=<AddBackward0>) tensor(1.2454, grad_fn=<AddBackward0>)
# tensor(4.5920, grad_fn=<AddBackward0>) tensor(1.2537, grad_fn=<AddBackward0>)
# tensor(4.5808, grad_fn=<AddBackward0>) tensor(1.2467, grad_fn=<AddBackward0>)
# tensor(4.5768, grad_fn=<AddBackward0>) tensor(1.2490, grad_fn=<AddBackward0>)
# tensor(4.5568, grad_fn=<AddBackward0>) tensor(1.2451, grad_fn=<AddBackward0>)
# tensor(4.5258, grad_fn=<AddBackward0>) tensor(1.2515, grad_fn=<AddBackward0>)
# tensor(4.4871, grad_fn=<AddBackward0>) tensor(1.2510, grad_fn=<AddBackward0>)
# tensor(4.4420, grad_fn=<AddBackward0>) tensor(1.2503, grad_fn=<AddBackward0>)
# tensor(4.3991, grad_fn=<AddBackward0>) tensor(1.2496, grad_fn=<AddBackward0>)
# tensor(4.3592, grad_fn=<AddBackward0>) tensor(1.2523, grad_fn=<AddBackward0>)
# tensor(4.3323, grad_fn=<AddBackward0>) tensor(1.2529, grad_fn=<AddBackward0>)
# tensor(4.3300, grad_fn=<AddBackward0>) tensor(1.2518, grad_fn=<AddBackward0>)
# tensor(4.3482, grad_fn=<AddBackward0>) tensor(1.2511, grad_fn=<AddBackward0>)
# tensor(4.3839, grad_fn=<AddBackward0>) tensor(1.2521, grad_fn=<AddBackward0>)
# tensor(4.4301, grad_fn=<AddBackward0>) tensor(1.2546, grad_fn=<AddBackward0>)
# tensor(4.4655, grad_fn=<AddBackward0>) tensor(1.2526, grad_fn=<AddBackward0>)
# tensor(4.4895, grad_fn=<AddBackward0>) tensor(1.2489, grad_fn=<AddBackward0>)
# tensor(4.5009, grad_fn=<AddBackward0>) tensor(1.2512, grad_fn=<AddBackward0>)
# tensor(4.5141, grad_fn=<AddBackward0>) tensor(1.2498, grad_fn=<AddBackward0>)
# tensor(4.5304, grad_fn=<AddBackward0>) tensor(1.2467, grad_fn=<AddBackward0>)
# tensor(4.5397, grad_fn=<AddBackward0>) tensor(1.2443, grad_fn=<AddBackward0>)
# tensor(4.5357, grad_fn=<AddBackward0>) tensor(1.2470, grad_fn=<AddBackward0>)
# tensor(4.5379, grad_fn=<AddBackward0>) tensor(1.2525, grad_fn=<AddBackward0>)
# tensor(4.5432, grad_fn=<AddBackward0>) tensor(1.2458, grad_fn=<AddBackward0>)
# tensor(4.5391, grad_fn=<AddBackward0>) tensor(1.2460, grad_fn=<AddBackward0>)
# tensor(4.5354, grad_fn=<AddBackward0>) tensor(1.2460, grad_fn=<AddBackward0>)
# tensor(4.5379, grad_fn=<AddBackward0>) tensor(1.2429, grad_fn=<AddBackward0>)
# tensor(4.5444, grad_fn=<AddBackward0>) tensor(1.2441, grad_fn=<AddBackward0>)
# tensor(4.5702, grad_fn=<AddBackward0>) tensor(1.2476, grad_fn=<AddBackward0>)
# tensor(4.5958, grad_fn=<AddBackward0>) tensor(1.2403, grad_fn=<AddBackward0>)
# tensor(4.6195, grad_fn=<AddBackward0>) tensor(1.2410, grad_fn=<AddBackward0>)
# tensor(4.6303, grad_fn=<AddBackward0>) tensor(1.2393, grad_fn=<AddBackward0>)
# tensor(4.6252, grad_fn=<AddBackward0>) tensor(1.2418, grad_fn=<AddBackward0>)
# tensor(4.6003, grad_fn=<AddBackward0>) tensor(1.2403, grad_fn=<AddBackward0>)
# tensor(4.5635, grad_fn=<AddBackward0>) tensor(1.2421, grad_fn=<AddBackward0>)
# tensor(4.5327, grad_fn=<AddBackward0>) tensor(1.2433, grad_fn=<AddBackward0>)
# tensor(4.5173, grad_fn=<AddBackward0>) tensor(1.2463, grad_fn=<AddBackward0>)
# tensor(4.5227, grad_fn=<AddBackward0>) tensor(1.2429, grad_fn=<AddBackward0>)
# tensor(4.5337, grad_fn=<AddBackward0>) tensor(1.2431, grad_fn=<AddBackward0>)
# tensor(4.5479, grad_fn=<AddBackward0>) tensor(1.2401, grad_fn=<AddBackward0>)
# tensor(4.5572, grad_fn=<AddBackward0>) tensor(1.2433, grad_fn=<AddBackward0>)
# tensor(4.5677, grad_fn=<AddBackward0>) tensor(1.2444, grad_fn=<AddBackward0>)
# tensor(4.5773, grad_fn=<AddBackward0>) tensor(1.2424, grad_fn=<AddBackward0>)
# tensor(4.5756, grad_fn=<AddBackward0>) tensor(1.2404, grad_fn=<AddBackward0>)
# tensor(4.5836, grad_fn=<AddBackward0>) tensor(1.2418, grad_fn=<AddBackward0>)
# tensor(4.5917, grad_fn=<AddBackward0>) tensor(1.2432, grad_fn=<AddBackward0>)
# tensor(4.5938, grad_fn=<AddBackward0>) tensor(1.2470, grad_fn=<AddBackward0>)
# tensor(4.5878, grad_fn=<AddBackward0>) tensor(1.2431, grad_fn=<AddBackward0>)
# tensor(4.5850, grad_fn=<AddBackward0>) tensor(1.2433, grad_fn=<AddBackward0>)
# tensor(4.5801, grad_fn=<AddBackward0>) tensor(1.2445, grad_fn=<AddBackward0>)
# tensor(4.5821, grad_fn=<AddBackward0>) tensor(1.2456, grad_fn=<AddBackward0>)
# tensor(4.5915, grad_fn=<AddBackward0>) tensor(1.2473, grad_fn=<AddBackward0>)
# tensor(4.6137, grad_fn=<AddBackward0>) tensor(1.2441, grad_fn=<AddBackward0>)
# tensor(4.6306, grad_fn=<AddBackward0>) tensor(1.2527, grad_fn=<AddBackward0>)
# tensor(4.6408, grad_fn=<AddBackward0>) tensor(1.2480, grad_fn=<AddBackward0>)
# tensor(4.6560, grad_fn=<AddBackward0>) tensor(1.2454, grad_fn=<AddBackward0>)
# tensor(4.6621, grad_fn=<AddBackward0>) tensor(1.2494, grad_fn=<AddBackward0>)
# tensor(4.6691, grad_fn=<AddBackward0>) tensor(1.2494, grad_fn=<AddBackward0>)
# tensor(4.6705, grad_fn=<AddBackward0>) tensor(1.2440, grad_fn=<AddBackward0>)
# tensor(4.6736, grad_fn=<AddBackward0>) tensor(1.2532, grad_fn=<AddBackward0>)
# tensor(4.6378, grad_fn=<AddBackward0>) tensor(1.2445, grad_fn=<AddBackward0>)
# tensor(4.5843, grad_fn=<AddBackward0>) tensor(1.2527, grad_fn=<AddBackward0>)
# tensor(4.5425, grad_fn=<AddBackward0>) tensor(1.2478, grad_fn=<AddBackward0>)
# tensor(4.5175, grad_fn=<AddBackward0>) tensor(1.2523, grad_fn=<AddBackward0>)
# tensor(4.4979, grad_fn=<AddBackward0>) tensor(1.2508, grad_fn=<AddBackward0>)
# tensor(4.4821, grad_fn=<AddBackward0>) tensor(1.2481, grad_fn=<AddBackward0>)
# tensor(4.4839, grad_fn=<AddBackward0>) tensor(1.2544, grad_fn=<AddBackward0>)
# tensor(4.4790, grad_fn=<AddBackward0>) tensor(1.2500, grad_fn=<AddBackward0>)
# tensor(4.4702, grad_fn=<AddBackward0>) tensor(1.2507, grad_fn=<AddBackward0>)
# tensor(4.4788, grad_fn=<AddBackward0>) tensor(1.2493, grad_fn=<AddBackward0>)
# tensor(4.5033, grad_fn=<AddBackward0>) tensor(1.2466, grad_fn=<AddBackward0>)
# tensor(4.5281, grad_fn=<AddBackward0>) tensor(1.2453, grad_fn=<AddBackward0>)
# tensor(4.5378, grad_fn=<AddBackward0>) tensor(1.2491, grad_fn=<AddBackward0>)
# tensor(4.5383, grad_fn=<AddBackward0>) tensor(1.2519, grad_fn=<AddBackward0>)
# tensor(4.5261, grad_fn=<AddBackward0>) tensor(1.2498, grad_fn=<AddBackward0>)
# tensor(4.5217, grad_fn=<AddBackward0>) tensor(1.2466, grad_fn=<AddBackward0>)
# tensor(4.5564, grad_fn=<AddBackward0>) tensor(1.2521, grad_fn=<AddBackward0>)
# tensor(4.6139, grad_fn=<AddBackward0>) tensor(1.2498, grad_fn=<AddBackward0>)
# tensor(4.6437, grad_fn=<AddBackward0>) tensor(1.2446, grad_fn=<AddBackward0>)
# tensor(4.6435, grad_fn=<AddBackward0>) tensor(1.2453, grad_fn=<AddBackward0>)
# tensor(4.6437, grad_fn=<AddBackward0>) tensor(1.2476, grad_fn=<AddBackward0>)
# tensor(4.6483, grad_fn=<AddBackward0>) tensor(1.2494, grad_fn=<AddBackward0>)
# tensor(4.6428, grad_fn=<AddBackward0>) tensor(1.2412, grad_fn=<AddBackward0>)
# tensor(4.6219, grad_fn=<AddBackward0>) tensor(1.2493, grad_fn=<AddBackward0>)
# tensor(4.5986, grad_fn=<AddBackward0>) tensor(1.2472, grad_fn=<AddBackward0>)
# tensor(4.5896, grad_fn=<AddBackward0>) tensor(1.2430, grad_fn=<AddBackward0>)
# tensor(4.5794, grad_fn=<AddBackward0>) tensor(1.2493, grad_fn=<AddBackward0>)
# tensor(4.5482, grad_fn=<AddBackward0>) tensor(1.2501, grad_fn=<AddBackward0>)
# tensor(4.5049, grad_fn=<AddBackward0>) tensor(1.2545, grad_fn=<AddBackward0>)
# tensor(4.4670, grad_fn=<AddBackward0>) tensor(1.2518, grad_fn=<AddBackward0>)
# tensor(4.4548, grad_fn=<AddBackward0>) tensor(1.2496, grad_fn=<AddBackward0>)
# tensor(4.4664, grad_fn=<AddBackward0>) tensor(1.2500, grad_fn=<AddBackward0>)
# tensor(4.4831, grad_fn=<AddBackward0>) tensor(1.2493, grad_fn=<AddBackward0>)
# tensor(4.5127, grad_fn=<AddBackward0>) tensor(1.2494, grad_fn=<AddBackward0>)
# tensor(4.5477, grad_fn=<AddBackward0>) tensor(1.2481, grad_fn=<AddBackward0>)
# tensor(4.5724, grad_fn=<AddBackward0>) tensor(1.2430, grad_fn=<AddBackward0>)
# tensor(4.5863, grad_fn=<AddBackward0>) tensor(1.2434, grad_fn=<AddBackward0>)
# tensor(4.5970, grad_fn=<AddBackward0>) tensor(1.2417, grad_fn=<AddBackward0>)
# tensor(4.6155, grad_fn=<AddBackward0>) tensor(1.2416, grad_fn=<AddBackward0>)
# tensor(4.6360, grad_fn=<AddBackward0>) tensor(1.2440, grad_fn=<AddBackward0>)
# tensor(4.6454, grad_fn=<AddBackward0>) tensor(1.2414, grad_fn=<AddBackward0>)
# tensor(4.6401, grad_fn=<AddBackward0>) tensor(1.2403, grad_fn=<AddBackward0>)
# tensor(4.6318, grad_fn=<AddBackward0>) tensor(1.2407, grad_fn=<AddBackward0>)
# tensor(4.6207, grad_fn=<AddBackward0>) tensor(1.2413, grad_fn=<AddBackward0>)
# tensor(4.5931, grad_fn=<AddBackward0>) tensor(1.2450, grad_fn=<AddBackward0>)
# tensor(4.5654, grad_fn=<AddBackward0>) tensor(1.2486, grad_fn=<AddBackward0>)
# tensor(4.5542, grad_fn=<AddBackward0>) tensor(1.2454, grad_fn=<AddBackward0>)
# tensor(4.5741, grad_fn=<AddBackward0>) tensor(1.2414, grad_fn=<AddBackward0>)
# tensor(4.6034, grad_fn=<AddBackward0>) tensor(1.2454, grad_fn=<AddBackward0>)
# tensor(4.6223, grad_fn=<AddBackward0>) tensor(1.2444, grad_fn=<AddBackward0>)
# tensor(4.6303, grad_fn=<AddBackward0>) tensor(1.2412, grad_fn=<AddBackward0>)
# tensor(4.6224, grad_fn=<AddBackward0>) tensor(1.2454, grad_fn=<AddBackward0>)
# tensor(4.6075, grad_fn=<AddBackward0>) tensor(1.2518, grad_fn=<AddBackward0>)
# tensor(4.5918, grad_fn=<AddBackward0>) tensor(1.2462, grad_fn=<AddBackward0>)
# tensor(4.5722, grad_fn=<AddBackward0>) tensor(1.2559, grad_fn=<AddBackward0>)
# tensor(4.5819, grad_fn=<AddBackward0>) tensor(1.2450, grad_fn=<AddBackward0>)
# tensor(4.6009, grad_fn=<AddBackward0>) tensor(1.2586, grad_fn=<AddBackward0>)
# tensor(4.6038, grad_fn=<AddBackward0>) tensor(1.2488, grad_fn=<AddBackward0>)
# tensor(4.5916, grad_fn=<AddBackward0>) tensor(1.2468, grad_fn=<AddBackward0>)
# tensor(4.5744, grad_fn=<AddBackward0>) tensor(1.2496, grad_fn=<AddBackward0>)
# tensor(4.5701, grad_fn=<AddBackward0>) tensor(1.2487, grad_fn=<AddBackward0>)
# tensor(4.5664, grad_fn=<AddBackward0>) tensor(1.2438, grad_fn=<AddBackward0>)
# tensor(4.5486, grad_fn=<AddBackward0>) tensor(1.2505, grad_fn=<AddBackward0>)
# tensor(4.5181, grad_fn=<AddBackward0>) tensor(1.2484, grad_fn=<AddBackward0>)
# tensor(4.4990, grad_fn=<AddBackward0>) tensor(1.2561, grad_fn=<AddBackward0>)
# tensor(4.4964, grad_fn=<AddBackward0>) tensor(1.2511, grad_fn=<AddBackward0>)
# tensor(4.5079, grad_fn=<AddBackward0>) tensor(1.2547, grad_fn=<AddBackward0>)
# tensor(4.5347, grad_fn=<AddBackward0>) tensor(1.2491, grad_fn=<AddBackward0>)
# tensor(4.5670, grad_fn=<AddBackward0>) tensor(1.2532, grad_fn=<AddBackward0>)
# tensor(4.5957, grad_fn=<AddBackward0>) tensor(1.2590, grad_fn=<AddBackward0>)
# tensor(4.6196, grad_fn=<AddBackward0>) tensor(1.2459, grad_fn=<AddBackward0>)
# tensor(4.6217, grad_fn=<AddBackward0>) tensor(1.2509, grad_fn=<AddBackward0>)
# tensor(4.6133, grad_fn=<AddBackward0>) tensor(1.2499, grad_fn=<AddBackward0>)
# tensor(4.6113, grad_fn=<AddBackward0>) tensor(1.2523, grad_fn=<AddBackward0>)
# tensor(4.6122, grad_fn=<AddBackward0>) tensor(1.2502, grad_fn=<AddBackward0>)
# tensor(4.6015, grad_fn=<AddBackward0>) tensor(1.2484, grad_fn=<AddBackward0>)
# tensor(4.6086, grad_fn=<AddBackward0>) tensor(1.2462, grad_fn=<AddBackward0>)
# tensor(4.6195, grad_fn=<AddBackward0>) tensor(1.2549, grad_fn=<AddBackward0>)
# tensor(4.6440, grad_fn=<AddBackward0>) tensor(1.2445, grad_fn=<AddBackward0>)
# tensor(4.6731, grad_fn=<AddBackward0>) tensor(1.2457, grad_fn=<AddBackward0>)
# tensor(4.6869, grad_fn=<AddBackward0>) tensor(1.2465, grad_fn=<AddBackward0>)
# tensor(4.6939, grad_fn=<AddBackward0>) tensor(1.2428, grad_fn=<AddBackward0>)
# tensor(4.7131, grad_fn=<AddBackward0>) tensor(1.2526, grad_fn=<AddBackward0>)
# tensor(4.7489, grad_fn=<AddBackward0>) tensor(1.2435, grad_fn=<AddBackward0>)
# tensor(4.7613, grad_fn=<AddBackward0>) tensor(1.2416, grad_fn=<AddBackward0>)
# tensor(4.7706, grad_fn=<AddBackward0>) tensor(1.2431, grad_fn=<AddBackward0>)
# tensor(4.7798, grad_fn=<AddBackward0>) tensor(1.2416, grad_fn=<AddBackward0>)
# tensor(4.7805, grad_fn=<AddBackward0>) tensor(1.2416, grad_fn=<AddBackward0>)
# tensor(4.7530, grad_fn=<AddBackward0>) tensor(1.2425, grad_fn=<AddBackward0>)
# tensor(4.7247, grad_fn=<AddBackward0>) tensor(1.2424, grad_fn=<AddBackward0>)
# tensor(4.6829, grad_fn=<AddBackward0>) tensor(1.2465, grad_fn=<AddBackward0>)
# tensor(4.6330, grad_fn=<AddBackward0>) tensor(1.2455, grad_fn=<AddBackward0>)
# tensor(4.5779, grad_fn=<AddBackward0>) tensor(1.2491, grad_fn=<AddBackward0>)
# tensor(4.5180, grad_fn=<AddBackward0>) tensor(1.2445, grad_fn=<AddBackward0>)
# tensor(4.4565, grad_fn=<AddBackward0>) tensor(1.2486, grad_fn=<AddBackward0>)
# tensor(4.4247, grad_fn=<AddBackward0>) tensor(1.2570, grad_fn=<AddBackward0>)
# tensor(4.4226, grad_fn=<AddBackward0>) tensor(1.2506, grad_fn=<AddBackward0>)
# tensor(4.4292, grad_fn=<AddBackward0>) tensor(1.2490, grad_fn=<AddBackward0>)
# tensor(4.4482, grad_fn=<AddBackward0>) tensor(1.2488, grad_fn=<AddBackward0>)
# tensor(4.5070, grad_fn=<AddBackward0>) tensor(1.2486, grad_fn=<AddBackward0>)
# tensor(4.5706, grad_fn=<AddBackward0>) tensor(1.2461, grad_fn=<AddBackward0>)
# tensor(4.6161, grad_fn=<AddBackward0>) tensor(1.2473, grad_fn=<AddBackward0>)
# tensor(4.6478, grad_fn=<AddBackward0>) tensor(1.2443, grad_fn=<AddBackward0>)
# tensor(4.6482, grad_fn=<AddBackward0>) tensor(1.2468, grad_fn=<AddBackward0>)
# tensor(4.6340, grad_fn=<AddBackward0>) tensor(1.2467, grad_fn=<AddBackward0>)
# tensor(4.6242, grad_fn=<AddBackward0>) tensor(1.2446, grad_fn=<AddBackward0>)
# tensor(4.5912, grad_fn=<AddBackward0>) tensor(1.2494, grad_fn=<AddBackward0>)
# tensor(4.5462, grad_fn=<AddBackward0>) tensor(1.2475, grad_fn=<AddBackward0>)
# tensor(4.5029, grad_fn=<AddBackward0>) tensor(1.2444, grad_fn=<AddBackward0>)
# tensor(4.4674, grad_fn=<AddBackward0>) tensor(1.2499, grad_fn=<AddBackward0>)
# tensor(4.4333, grad_fn=<AddBackward0>) tensor(1.2472, grad_fn=<AddBackward0>)
# tensor(4.4115, grad_fn=<AddBackward0>) tensor(1.2539, grad_fn=<AddBackward0>)
# tensor(4.4156, grad_fn=<AddBackward0>) tensor(1.2471, grad_fn=<AddBackward0>)
# tensor(4.4361, grad_fn=<AddBackward0>) tensor(1.2537, grad_fn=<AddBackward0>)
# tensor(4.4619, grad_fn=<AddBackward0>) tensor(1.2531, grad_fn=<AddBackward0>)
# tensor(4.4834, grad_fn=<AddBackward0>) tensor(1.2502, grad_fn=<AddBackward0>)
# tensor(4.5294, grad_fn=<AddBackward0>) tensor(1.2481, grad_fn=<AddBackward0>)
# tensor(4.5722, grad_fn=<AddBackward0>) tensor(1.2537, grad_fn=<AddBackward0>)
# tensor(4.5907, grad_fn=<AddBackward0>) tensor(1.2425, grad_fn=<AddBackward0>)
# tensor(4.5849, grad_fn=<AddBackward0>) tensor(1.2544, grad_fn=<AddBackward0>)
# tensor(4.5786, grad_fn=<AddBackward0>) tensor(1.2502, grad_fn=<AddBackward0>)
# tensor(4.5640, grad_fn=<AddBackward0>) tensor(1.2510, grad_fn=<AddBackward0>)
# tensor(4.5566, grad_fn=<AddBackward0>) tensor(1.2519, grad_fn=<AddBackward0>)
# tensor(4.5511, grad_fn=<AddBackward0>) tensor(1.2539, grad_fn=<AddBackward0>)
# tensor(4.5253, grad_fn=<AddBackward0>) tensor(1.2474, grad_fn=<AddBackward0>)
# tensor(4.4950, grad_fn=<AddBackward0>) tensor(1.2551, grad_fn=<AddBackward0>)
# tensor(4.4838, grad_fn=<AddBackward0>) tensor(1.2514, grad_fn=<AddBackward0>)
# tensor(4.5006, grad_fn=<AddBackward0>) tensor(1.2567, grad_fn=<AddBackward0>)
# tensor(4.5403, grad_fn=<AddBackward0>) tensor(1.2520, grad_fn=<AddBackward0>)
# tensor(4.5948, grad_fn=<AddBackward0>) tensor(1.2504, grad_fn=<AddBackward0>)
# tensor(4.6461, grad_fn=<AddBackward0>) tensor(1.2476, grad_fn=<AddBackward0>)
# tensor(4.6700, grad_fn=<AddBackward0>) tensor(1.2463, grad_fn=<AddBackward0>)
# tensor(4.7110, grad_fn=<AddBackward0>) tensor(1.2446, grad_fn=<AddBackward0>)
# tensor(4.7369, grad_fn=<AddBackward0>) tensor(1.2461, grad_fn=<AddBackward0>)
# tensor(4.7252, grad_fn=<AddBackward0>) tensor(1.2457, grad_fn=<AddBackward0>)
# tensor(4.7072, grad_fn=<AddBackward0>) tensor(1.2493, grad_fn=<AddBackward0>)
# tensor(4.6818, grad_fn=<AddBackward0>) tensor(1.2441, grad_fn=<AddBackward0>)
# tensor(4.6388, grad_fn=<AddBackward0>) tensor(1.2458, grad_fn=<AddBackward0>)
# tensor(4.5923, grad_fn=<AddBackward0>) tensor(1.2477, grad_fn=<AddBackward0>)
# tensor(4.5706, grad_fn=<AddBackward0>) tensor(1.2492, grad_fn=<AddBackward0>)
# tensor(4.5741, grad_fn=<AddBackward0>) tensor(1.2517, grad_fn=<AddBackward0>)
# tensor(4.5935, grad_fn=<AddBackward0>) tensor(1.2499, grad_fn=<AddBackward0>)
# tensor(4.6262, grad_fn=<AddBackward0>) tensor(1.2480, grad_fn=<AddBackward0>)
# tensor(4.6457, grad_fn=<AddBackward0>) tensor(1.2471, grad_fn=<AddBackward0>)
# tensor(4.6725, grad_fn=<AddBackward0>) tensor(1.2450, grad_fn=<AddBackward0>)
# tensor(4.6871, grad_fn=<AddBackward0>) tensor(1.2435, grad_fn=<AddBackward0>)
# tensor(4.6943, grad_fn=<AddBackward0>) tensor(1.2411, grad_fn=<AddBackward0>)
# tensor(4.6904, grad_fn=<AddBackward0>) tensor(1.2457, grad_fn=<AddBackward0>)
# tensor(4.6768, grad_fn=<AddBackward0>) tensor(1.2424, grad_fn=<AddBackward0>)
# tensor(4.6619, grad_fn=<AddBackward0>) tensor(1.2411, grad_fn=<AddBackward0>)
# tensor(4.6443, grad_fn=<AddBackward0>) tensor(1.2486, grad_fn=<AddBackward0>)
# tensor(4.6279, grad_fn=<AddBackward0>) tensor(1.2436, grad_fn=<AddBackward0>)
# tensor(4.6154, grad_fn=<AddBackward0>) tensor(1.2475, grad_fn=<AddBackward0>)
# tensor(4.6048, grad_fn=<AddBackward0>) tensor(1.2610, grad_fn=<AddBackward0>)
# tensor(4.5704, grad_fn=<AddBackward0>) tensor(1.2484, grad_fn=<AddBackward0>)
# tensor(4.5600, grad_fn=<AddBackward0>) tensor(1.2530, grad_fn=<AddBackward0>)
# tensor(4.5688, grad_fn=<AddBackward0>) tensor(1.2552, grad_fn=<AddBackward0>)
# tensor(4.5784, grad_fn=<AddBackward0>) tensor(1.2585, grad_fn=<AddBackward0>)
# tensor(4.5868, grad_fn=<AddBackward0>) tensor(1.2489, grad_fn=<AddBackward0>)
# tensor(4.5909, grad_fn=<AddBackward0>) tensor(1.2627, grad_fn=<AddBackward0>)
# tensor(4.6132, grad_fn=<AddBackward0>) tensor(1.2496, grad_fn=<AddBackward0>)
# tensor(4.6480, grad_fn=<AddBackward0>) tensor(1.2553, grad_fn=<AddBackward0>)
# tensor(4.6745, grad_fn=<AddBackward0>) tensor(1.2492, grad_fn=<AddBackward0>)
# tensor(4.6923, grad_fn=<AddBackward0>) tensor(1.2522, grad_fn=<AddBackward0>)
# tensor(4.6998, grad_fn=<AddBackward0>) tensor(1.2452, grad_fn=<AddBackward0>)
# tensor(4.6934, grad_fn=<AddBackward0>) tensor(1.2492, grad_fn=<AddBackward0>)
# tensor(4.6987, grad_fn=<AddBackward0>) tensor(1.2516, grad_fn=<AddBackward0>)
# tensor(4.6992, grad_fn=<AddBackward0>) tensor(1.2481, grad_fn=<AddBackward0>)
# tensor(4.6899, grad_fn=<AddBackward0>) tensor(1.2459, grad_fn=<AddBackward0>)
# tensor(4.6669, grad_fn=<AddBackward0>) tensor(1.2473, grad_fn=<AddBackward0>)
# tensor(4.6554, grad_fn=<AddBackward0>) tensor(1.2480, grad_fn=<AddBackward0>)
# tensor(4.6450, grad_fn=<AddBackward0>) tensor(1.2543, grad_fn=<AddBackward0>)
# tensor(4.6152, grad_fn=<AddBackward0>) tensor(1.2489, grad_fn=<AddBackward0>)
# tensor(4.5784, grad_fn=<AddBackward0>) tensor(1.2523, grad_fn=<AddBackward0>)
# tensor(4.5543, grad_fn=<AddBackward0>) tensor(1.2494, grad_fn=<AddBackward0>)
# tensor(4.5471, grad_fn=<AddBackward0>) tensor(1.2512, grad_fn=<AddBackward0>)
# tensor(4.5648, grad_fn=<AddBackward0>) tensor(1.2577, grad_fn=<AddBackward0>)
# tensor(4.5856, grad_fn=<AddBackward0>) tensor(1.2488, grad_fn=<AddBackward0>)
# tensor(4.6199, grad_fn=<AddBackward0>) tensor(1.2502, grad_fn=<AddBackward0>)
# tensor(4.6666, grad_fn=<AddBackward0>) tensor(1.2479, grad_fn=<AddBackward0>)
# tensor(4.7223, grad_fn=<AddBackward0>) tensor(1.2441, grad_fn=<AddBackward0>)
# tensor(4.7765, grad_fn=<AddBackward0>) tensor(1.2484, grad_fn=<AddBackward0>)
# tensor(4.8063, grad_fn=<AddBackward0>) tensor(1.2460, grad_fn=<AddBackward0>)
# tensor(4.8084, grad_fn=<AddBackward0>) tensor(1.2470, grad_fn=<AddBackward0>)
# tensor(4.8063, grad_fn=<AddBackward0>) tensor(1.2470, grad_fn=<AddBackward0>)
# tensor(4.8006, grad_fn=<AddBackward0>) tensor(1.2522, grad_fn=<AddBackward0>)
# tensor(4.7664, grad_fn=<AddBackward0>) tensor(1.2425, grad_fn=<AddBackward0>)
# tensor(4.6992, grad_fn=<AddBackward0>) tensor(1.2499, grad_fn=<AddBackward0>)

# %%
x1=torch.tensor([-0.62,-0.54])
x2=torch.tensor([0.49,-0.02])
t_array=np.linspace(0,1,101)
Straight_Loss_array=np.zeros(len(t_array))
Optimized_Loss_array=np.zeros(len(t_array))
def two_wells_with_bump(x, y):
    well1 = -np.exp(-3*((x-0.5)**2 + y**2))
    well2 = -np.exp(-3*((x+0.5)**2 + (y+0.5)**2))
    bump1 = np.exp(-15*((x+0.2)**2 + (y+0.4)**2))
    bump2 = np.exp(-15*((x+0.0)**2 + (y-0.3)**2))
    return well1 + well2 + bump1+ bump2+1.0190055296306975
x = np.linspace(-1, 1, 200)
y = np.linspace(-1, 1, 200)
X, Y = np.meshgrid(x, y)
Z = two_wells_with_bump(X, Y)
x_vals = np.linspace(x1[0], x2[0], len(t_array))
y_vals = np.linspace(x1[1], x2[1], len(t_array))
for i in range(len(t_array)):
    Straight_Loss_array[i]=two_wells_with_bump(x_vals[i],y_vals[i])
    Optimized_Loss_array[i]=two_wells_with_bump(Min_path.detach().numpy()[i,0],Min_path.detach().numpy()[i,1])
plt.figure(figsize=(8,6))
contours = plt.contour(X, Y, Z, levels=50, cmap='viridis')
plt.colorbar(contours)
plt.plot(x_vals, y_vals, label="Linear Interpolated Line", color='blue',linestyle='--')

plt.title('2D examples')
plt.xlabel('x')
plt.ylabel('y')
plt.plot(Min_path.detach().numpy()[:,0],Min_path.detach().numpy()[:,1],label="Optimized Path")
plt.legend()
plt.xlim([-0.8,0.8])
plt.ylim([-0.75,0.6])
plt.show()
plt.plot(Straight_Loss_array,label="Linear Interpolated Line")
plt.plot(Optimized_Loss_array,label="Optimized Path")
plt.xlabel("t")
plt.ylabel("Loss")
plt.title("Loss along Straight Path vs Optimized Path")
plt.legend()
plt.show()
# Out:
# C:\Users\19178\AppData\Local\Temp\ipykernel_56704\4021861223.py:7: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   well1 = -np.exp(-3*((x-0.5)**2 + y**2))
# C:\Users\19178\AppData\Local\Temp\ipykernel_56704\4021861223.py:8: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   well2 = -np.exp(-3*((x+0.5)**2 + (y+0.5)**2))
# C:\Users\19178\AppData\Local\Temp\ipykernel_56704\4021861223.py:9: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   bump1 = np.exp(-15*((x+0.2)**2 + (y+0.4)**2))
# C:\Users\19178\AppData\Local\Temp\ipykernel_56704\4021861223.py:10: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   bump2 = np.exp(-15*((x+0.0)**2 + (y-0.3)**2))
